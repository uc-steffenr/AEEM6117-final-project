# %%
import numpy as np
import matplotlib.pyplot as plt

from system import System

# %%
rho = np.array([0.5, 0.5, 0.5])
m = np.array([250., 25., 25.])
I = np.array([25., 2.5, 2.5])
b = np.array([1., 1., 1.])

# y0 = np.zeros(6)
y0 = np.array([0., 0., 0., np.deg2rad(0.), np.deg2rad(10.), 0.])

parameters = dict(rho=rho,
                  m=m,
                  I=I,
                  b=b)

sys = System(y0, parameters)

# %%
t, y, u = sys.run()

# %%
y.shape
# Out:
# (6, 1501)

# %%
plt.plot(t, np.rad2deg(y[0, :]))
plt.show()

# %%
plt.plot(t, np.rad2deg(y[1, :]))
plt.show()

# %%
plt.plot(t, np.rad2deg(y[2, :]))
plt.show()

# %%
plt.plot(t, u)
plt.show()

# %%
from matplotlib.animation import FuncAnimation
from utils import load_position_func

ys = y.T

get_pos = load_position_func()

rs0, r10, r20 = get_pos(ys[0, :], rho)

# %%
rs0
# Out:
# array([[0],
#        [0]])
